# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv("C:/Users/Home/Downloads/archive/diabetes.csv")

# %%
df.info
# Out:
# <bound method DataFrame.info of      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# ...

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
y= df['Outcome']
X = df[["Pregnancies","Glucose","BloodPressure","SkinThickness","Insulin","BMI","DiabetesPedigreeFunction","Age"]]

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2)

# %%
X_train_n= X_train.copy()

# %%
X_test_n= X_test.copy()

# %%
norm = MinMaxScaler().fit(X_train_n)
x_train_norm = norm.transform(X_train_n)
x_test_norm = norm.transform(X_test_n)

# %%
x_train_norm_df = pd.DataFrame(x_train_norm)
x_test_norm_df = pd.DataFrame(x_test_norm)

# %%
x_train_norm_df.columns = X_train_n.columns

# %%
x_train_norm_df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   614.000000  614.000000     614.000000     614.000000  614.000000
# mean      0.222265    0.606477       0.567883       0.201971    0.094774
# std       0.197180    0.165109       0.160089       0.162760    0.142210
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       0.058824    0.497487       0.524590       0.000000    0.000000
# 50%       0.176471    0.582915       0.590164       0.222222    0.027187
# 75%       0.352941    0.712312       0.655738       0.323232    0.143617
# max       1.000000    1.000000       1.000000       1.000000    1.000000
#
#               BMI  DiabetesPedigreeFunction         Age
# count  614.000000                614.000000  614.000000
# mean     0.474944                  0.168652    0.207383
# std      0.117317                  0.147342    0.199938
# min      0.000000                  0.000000    0.000000
# ...

# %%
x_train_norm_df
# Out:
#      Pregnancies   Glucose  BloodPressure  SkinThickness   Insulin       BMI  \
# 0       0.176471  0.884422       0.704918       0.272727  0.184397  0.496274
# 1       0.058824  0.457286       0.524590       0.242424  0.000000  0.435171
# 2       0.705882  0.442211       0.606557       0.404040  0.063830  0.526080
# 3       0.000000  0.628141       0.557377       0.000000  0.000000  0.368107
# 4       0.117647  0.643216       0.524590       0.424242  0.000000  0.596125
# ..           ...       ...            ...            ...       ...       ...
# 609     0.117647  0.427136       0.532787       0.000000  0.000000  0.590164
# 610     0.058824  0.356784       0.393443       0.181818  0.089835  0.304024
# 611     0.294118  0.427136       0.606557       0.222222  0.000000  0.432191
# 612     0.058824  0.437186       0.491803       0.373737  0.088652  0.554396
# 613     0.470588  0.984925       0.622951       0.292929  0.330969  0.558867
#
#      DiabetesPedigreeFunction       Age
# ...

# %%
x_test_norm_df
# Out:
#             0         1         2         3         4         5         6  \
# 0    0.000000  0.572864  0.655738  0.343434  0.336879  0.658718  0.035118
# 1    0.352941  0.979899  0.573770  0.000000  0.000000  0.460507  0.104069
# 2    0.764706  0.728643  0.672131  0.191919  0.130024  0.330849  0.068522
# 3    0.294118  0.582915  0.606557  0.292929  0.000000  0.481371  0.246253
# 4    0.882353  0.683417  0.573770  0.323232  0.130024  0.552906  0.029122
# ..        ...       ...       ...       ...       ...       ...       ...
# 149  0.411765  0.532663  0.491803  0.242424  0.000000  0.394933  0.090364
# 150  0.117647  0.577889  0.524590  0.222222  0.000000  0.459016  0.143897
# 151  0.235294  0.758794  0.737705  0.383838  0.000000  0.442623  0.089507
# 152  0.058824  0.462312  0.508197  0.252525  0.048463  0.290611  0.170021
# 153  0.000000  0.658291  0.540984  0.404040  0.000000  0.511177  0.047537
#
#             7
# 0    0.100000
# 1    0.166667
# 2    0.600000
# 3    0.233333
# ...

# %%
x_test_norm_df
# Out:
#             0         1         2         3         4         5         6  \
# 0    0.000000  0.572864  0.655738  0.343434  0.336879  0.658718  0.035118
# 1    0.352941  0.979899  0.573770  0.000000  0.000000  0.460507  0.104069
# 2    0.764706  0.728643  0.672131  0.191919  0.130024  0.330849  0.068522
# 3    0.294118  0.582915  0.606557  0.292929  0.000000  0.481371  0.246253
# 4    0.882353  0.683417  0.573770  0.323232  0.130024  0.552906  0.029122
# ..        ...       ...       ...       ...       ...       ...       ...
# 149  0.411765  0.532663  0.491803  0.242424  0.000000  0.394933  0.090364
# 150  0.117647  0.577889  0.524590  0.222222  0.000000  0.459016  0.143897
# 151  0.235294  0.758794  0.737705  0.383838  0.000000  0.442623  0.089507
# 152  0.058824  0.462312  0.508197  0.252525  0.048463  0.290611  0.170021
# 153  0.000000  0.658291  0.540984  0.404040  0.000000  0.511177  0.047537
#
#             7
# 0    0.100000
# 1    0.166667
# 2    0.600000
# 3    0.233333
# ...

# %%
X_train
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 588            3      176             86             27      156  33.3
# 240            1       91             64             24        0  29.2
# 358           12       88             74             40       54  35.3
# 626            0      125             68              0        0  24.7
# 267            2      128             64             42        0  40.0
# ..           ...      ...            ...            ...      ...   ...
# 104            2       85             65              0        0  39.6
# 97             1       71             48             18       76  20.4
# 218            5       85             74             22        0  29.0
# 377            1       87             60             37       75  37.2
# 206            8      196             76             29      280  37.5
#
#      DiabetesPedigreeFunction  Age
# 588                     1.154   52
# 240                     0.192   21
# ...

# %%
y_train
# Out:
# 588    1
# 240    0
# 358    0
# 626    0
# 267    0
#       ..
# 104    0
# 97     0
# 218    1
# 377    0
# 206    1
# Name: Outcome, Length: 614, dtype: int64

# %%
x_train_norm_df.to_csv('train_norm.csv')

# %%
x_train_norm_df.to_csv('train_norm.csv', index=False)

# %%
X_test
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 162            0      114             80             34      285  44.2
# 675            6      195             70              0        0  30.9
# 28            13      145             82             19      110  22.2
# 386            5      116             74             29        0  32.3
# 88            15      136             70             32      110  37.1
# ..           ...      ...            ...            ...      ...   ...
# 276            7      106             60             24        0  26.5
# 423            2      115             64             22        0  30.8
# 160            4      151             90             38        0  29.7
# 607            1       92             62             25       41  19.5
# 397            0      131             66             40        0  34.3
#
#      DiabetesPedigreeFunction  Age
# 162                     0.167   27
# 675                     0.328   31
# ...

# %%
X_test_norm
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 X_test_norm
#
# NameError: name 'X_test_norm' is not defined

# %%
x_test_norm
# Out:
# array([[0.        , 0.57286432, 0.6557377 , ..., 0.65871833, 0.03511777,
#         0.1       ],
#        [0.35294118, 0.9798995 , 0.57377049, ..., 0.46050671, 0.10406852,
#         0.16666667],
#        [0.76470588, 0.72864322, 0.67213115, ..., 0.33084948, 0.06852248,
#         0.6       ],
#        ...,
#        [0.23529412, 0.75879397, 0.73770492, ..., 0.44262295, 0.08950749,
#         0.25      ],
#        [0.05882353, 0.46231156, 0.50819672, ..., 0.29061103, 0.17002141,
#         0.06666667],
#        [0.        , 0.65829146, 0.54098361, ..., 0.51117735, 0.04753747,
#         0.01666667]])

# %%
x_test_norm_df
# Out:
#             0         1         2         3         4         5         6  \
# 0    0.000000  0.572864  0.655738  0.343434  0.336879  0.658718  0.035118
# 1    0.352941  0.979899  0.573770  0.000000  0.000000  0.460507  0.104069
# 2    0.764706  0.728643  0.672131  0.191919  0.130024  0.330849  0.068522
# 3    0.294118  0.582915  0.606557  0.292929  0.000000  0.481371  0.246253
# 4    0.882353  0.683417  0.573770  0.323232  0.130024  0.552906  0.029122
# ..        ...       ...       ...       ...       ...       ...       ...
# 149  0.411765  0.532663  0.491803  0.242424  0.000000  0.394933  0.090364
# 150  0.117647  0.577889  0.524590  0.222222  0.000000  0.459016  0.143897
# 151  0.235294  0.758794  0.737705  0.383838  0.000000  0.442623  0.089507
# 152  0.058824  0.462312  0.508197  0.252525  0.048463  0.290611  0.170021
# 153  0.000000  0.658291  0.540984  0.404040  0.000000  0.511177  0.047537
#
#             7
# 0    0.100000
# 1    0.166667
# 2    0.600000
# 3    0.233333
# ...

# %%
x_train_norm
# Out:
# array([[0.17647059, 0.88442211, 0.70491803, ..., 0.49627422, 0.45781585,
#         0.51666667],
#        [0.05882353, 0.45728643, 0.52459016, ..., 0.43517139, 0.04582441,
#         0.        ],
#        [0.70588235, 0.44221106, 0.60655738, ..., 0.52608048, 0.1254818 ,
#         0.45      ],
#        ...,
#        [0.29411765, 0.42713568, 0.60655738, ..., 0.43219076, 0.48779443,
#         0.18333333],
#        [0.05882353, 0.43718593, 0.49180328, ..., 0.55439642, 0.18158458,
#         0.01666667],
#        [0.47058824, 0.98492462, 0.62295082, ..., 0.55886736, 0.22269807,
#         0.6       ]])

# %%
x_test_norm_df.to_csv('test_norm.csv')

# %%
x_test_norm_df.to_csv('test_norm.csv', index=False)
